# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
# Size set to 20 to limit API calls. Once everything is finished, change 10 to 2000
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 772

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?"

city_url = f"{url}&q={city}&appid={weather_api_key}&units=metric"
#city_url = url + "&q=" + city.replace(" ","+") + "&appid=" + weather_api_key + "&units=imperial"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?&q=saint-augustin&appid=497c45a5a89fff05c0f388528e0cc402&units=metric

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
#print(city_weather)

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+") + "&appid=" + weather_api_key + "&units=metric"
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chapais
# Processing Record 2 of Set 1 | airai
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | edremit
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | hokitika
# Processing Record 13 of Set 1 | nantucket
# Processing Record 14 of Set 1 | cairns
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | bengkulu
# Processing Record 17 of Set 1 | bandarbeyla
# Processing Record 18 of Set 1 | tsiroanomandidy
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | atar
# Processing Record 21 of Set 1 | banda aceh
# Processing Record 22 of Set 1 | khanpur
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | olafsvik
# Processing Record 25 of Set 1 | beringovskiy
# Processing Record 26 of Set 1 | kawalu
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | vaitape
# Processing Record 30 of Set 1 | veinticinco de mayo
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | saint-gaudens
# Processing Record 33 of Set 1 | sibiti
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | san policarpo
# Processing Record 38 of Set 1 | saldanha
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | torbay
# Processing Record 41 of Set 1 | aranos
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | hobyo
# Processing Record 45 of Set 1 | te anau
# Processing Record 46 of Set 1 | vestmanna
# Processing Record 47 of Set 1 | san patricio
# Processing Record 48 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 1 | providencia
# Processing Record 50 of Set 1 | amahai
# Processing Record 1 of Set 2 | bethel
# Processing Record 2 of Set 2 | lavrentiya
# Processing Record 3 of Set 2 | wabana
# Processing Record 4 of Set 2 | nikolskoye
# Processing Record 5 of Set 2 | lagos
# Processing Record 6 of Set 2 | upernavik
# Processing Record 7 of Set 2 | altay
# Processing Record 8 of Set 2 | presidente olegario
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | tres arroyos
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | christchurch
# Processing Record 15 of Set 2 | isangel
# Processing Record 16 of Set 2 | astorga
# Processing Record 17 of Set 2 | ilulissat
# Processing Record 18 of Set 2 | tobol
# Processing Record 19 of Set 2 | srednekolymsk
# Processing Record 20 of Set 2 | chuy
# Processing Record 21 of Set 2 | yulara
# Processing Record 22 of Set 2 | solton
# Processing Record 23 of Set 2 | havoysund
# Processing Record 24 of Set 2 | namie
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | huambo
# Processing Record 27 of Set 2 | vao
# Processing Record 28 of Set 2 | sao joao da barra
# Processing Record 29 of Set 2 | ulladulla
# Processing Record 30 of Set 2 | simao
# Processing Record 31 of Set 2 | port lincoln
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | doha
# Processing Record 34 of Set 2 | mullaitivu
# City not found. Skipping...
# Processing Record 35 of Set 2 | avarua
# Processing Record 36 of Set 2 | bell ville
# Processing Record 37 of Set 2 | mayumba
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | buraydah
# Processing Record 40 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 2 | san quintin
# Processing Record 42 of Set 2 | qaanaaq
# Processing Record 43 of Set 2 | pisco
# Processing Record 44 of Set 2 | ruidoso
# Processing Record 45 of Set 2 | auki
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | grafton
# Processing Record 48 of Set 2 | haines junction
# Processing Record 49 of Set 2 | okhotsk
# Processing Record 50 of Set 2 | hatsukaichi
# Processing Record 1 of Set 3 | bathsheba
# Processing Record 2 of Set 3 | cabo san lucas
# Processing Record 3 of Set 3 | rybinsk
# Processing Record 4 of Set 3 | ambikapur
# Processing Record 5 of Set 3 | saint-philippe
# Processing Record 6 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 3 | puerto ayora
# Processing Record 8 of Set 3 | heihe
# Processing Record 9 of Set 3 | kirakira
# Processing Record 10 of Set 3 | port hawkesbury
# Processing Record 11 of Set 3 | broome
# Processing Record 12 of Set 3 | djenne
# Processing Record 13 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 3 | naze
# Processing Record 15 of Set 3 | buenos aires
# Processing Record 16 of Set 3 | jamestown
# Processing Record 17 of Set 3 | sinjar
# Processing Record 18 of Set 3 | elk
# Processing Record 19 of Set 3 | chokurdakh
# Processing Record 20 of Set 3 | nagorsk
# Processing Record 21 of Set 3 | kathmandu
# Processing Record 22 of Set 3 | talnakh
# Processing Record 23 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 3 | mikun
# Processing Record 25 of Set 3 | clyde river
# Processing Record 26 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 3 | cockburn town
# Processing Record 28 of Set 3 | khatanga
# Processing Record 29 of Set 3 | valjala
# City not found. Skipping...
# Processing Record 30 of Set 3 | butaritari
# Processing Record 31 of Set 3 | gimbi
# Processing Record 32 of Set 3 | dipkarpaz
# City not found. Skipping...
# Processing Record 33 of Set 3 | hovd
# Processing Record 34 of Set 3 | gallup
# Processing Record 35 of Set 3 | sayyan
# Processing Record 36 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 3 | joniskis
# Processing Record 38 of Set 3 | mariental
# Processing Record 39 of Set 3 | kaitangata
# Processing Record 40 of Set 3 | paracuru
# Processing Record 41 of Set 3 | launceston
# Processing Record 42 of Set 3 | ponta do sol
# Processing Record 43 of Set 3 | ornskoldsvik
# Processing Record 44 of Set 3 | savannah bight
# Processing Record 45 of Set 3 | lompoc
# Processing Record 46 of Set 3 | saint anthony
# Processing Record 47 of Set 3 | zavyalovo
# Processing Record 48 of Set 3 | camana
# Processing Record 49 of Set 3 | birakan
# Processing Record 50 of Set 3 | arrifes
# Processing Record 1 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 4 | alofi
# Processing Record 3 of Set 4 | hasaki
# Processing Record 4 of Set 4 | esperance
# Processing Record 5 of Set 4 | santa maria
# Processing Record 6 of Set 4 | koundara
# Processing Record 7 of Set 4 | moose factory
# Processing Record 8 of Set 4 | lasa
# Processing Record 9 of Set 4 | tocache
# Processing Record 10 of Set 4 | tawang
# Processing Record 11 of Set 4 | half moon bay
# Processing Record 12 of Set 4 | college
# Processing Record 13 of Set 4 | arlit
# Processing Record 14 of Set 4 | coquimbo
# Processing Record 15 of Set 4 | taoudenni
# Processing Record 16 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 4 | baijiantan
# Processing Record 18 of Set 4 | paragominas
# Processing Record 19 of Set 4 | hermanus
# Processing Record 20 of Set 4 | portland
# Processing Record 21 of Set 4 | kijaba
# City not found. Skipping...
# Processing Record 22 of Set 4 | yuli
# Processing Record 23 of Set 4 | ribeira grande
# Processing Record 24 of Set 4 | palma di montechiaro
# Processing Record 25 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 26 of Set 4 | khani
# Processing Record 27 of Set 4 | san cristobal
# Processing Record 28 of Set 4 | poum
# Processing Record 29 of Set 4 | liuzhou
# Processing Record 30 of Set 4 | wuning
# Processing Record 31 of Set 4 | north platte
# Processing Record 32 of Set 4 | norman wells
# Processing Record 33 of Set 4 | rabo de peixe
# Processing Record 34 of Set 4 | nyanza
# Processing Record 35 of Set 4 | scottsburgh
# City not found. Skipping...
# Processing Record 36 of Set 4 | severo-kurilsk
# Processing Record 37 of Set 4 | lebu
# Processing Record 38 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 4 | nome
# Processing Record 40 of Set 4 | mahebourg
# Processing Record 41 of Set 4 | kalmunai
# Processing Record 42 of Set 4 | taburao
# City not found. Skipping...
# Processing Record 43 of Set 4 | kondrovo
# Processing Record 44 of Set 4 | arak
# Processing Record 45 of Set 4 | coihaique
# Processing Record 46 of Set 4 | saskylakh
# Processing Record 47 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 4 | hofn
# Processing Record 49 of Set 4 | sompeta
# Processing Record 50 of Set 4 | longyearbyen
# Processing Record 1 of Set 5 | ayagoz
# Processing Record 2 of Set 5 | riyaq
# City not found. Skipping...
# Processing Record 3 of Set 5 | tura
# Processing Record 4 of Set 5 | saint-georges
# Processing Record 5 of Set 5 | kruisfontein
# Processing Record 6 of Set 5 | viedma
# Processing Record 7 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 5 | sept-iles
# Processing Record 9 of Set 5 | tashla
# Processing Record 10 of Set 5 | salalah
# Processing Record 11 of Set 5 | partapur
# Processing Record 12 of Set 5 | santiago
# Processing Record 13 of Set 5 | rio branco do sul
# Processing Record 14 of Set 5 | constitucion
# Processing Record 15 of Set 5 | tigil
# Processing Record 16 of Set 5 | victoria
# Processing Record 17 of Set 5 | salinas
# Processing Record 18 of Set 5 | mustang
# Processing Record 19 of Set 5 | zhezkazgan
# Processing Record 20 of Set 5 | itoman
# Processing Record 21 of Set 5 | pokosnoye
# Processing Record 22 of Set 5 | cherskiy
# Processing Record 23 of Set 5 | namatanai
# Processing Record 24 of Set 5 | krasnoarmeyskiy
# Processing Record 25 of Set 5 | am timan
# Processing Record 26 of Set 5 | monopoli
# Processing Record 27 of Set 5 | andenes
# Processing Record 28 of Set 5 | hualmay
# Processing Record 29 of Set 5 | flin flon
# Processing Record 30 of Set 5 | ostersund
# Processing Record 31 of Set 5 | harbour breton
# Processing Record 32 of Set 5 | faanui
# Processing Record 33 of Set 5 | ahipara
# Processing Record 34 of Set 5 | palmer
# Processing Record 35 of Set 5 | miles city
# Processing Record 36 of Set 5 | tuatapere
# Processing Record 37 of Set 5 | zhigansk
# Processing Record 38 of Set 5 | saint-francois
# Processing Record 39 of Set 5 | moron
# Processing Record 40 of Set 5 | meulaboh
# Processing Record 41 of Set 5 | lyuban
# Processing Record 42 of Set 5 | shaowu
# Processing Record 43 of Set 5 | santa luzia
# Processing Record 44 of Set 5 | san antonio
# Processing Record 45 of Set 5 | mocuba
# Processing Record 46 of Set 5 | cidreira
# Processing Record 47 of Set 5 | vostok
# Processing Record 48 of Set 5 | umm lajj
# Processing Record 49 of Set 5 | biltine
# Processing Record 50 of Set 5 | tamandare
# Processing Record 1 of Set 6 | mar del plata
# Processing Record 2 of Set 6 | parras
# City not found. Skipping...
# Processing Record 3 of Set 6 | ostrovnoy
# Processing Record 4 of Set 6 | souillac
# Processing Record 5 of Set 6 | frumoasa
# Processing Record 6 of Set 6 | svolvaer
# Processing Record 7 of Set 6 | ainazi
# Processing Record 8 of Set 6 | ancud
# Processing Record 9 of Set 6 | rocha
# Processing Record 10 of Set 6 | grindavik
# Processing Record 11 of Set 6 | los llanos de aridane
# Processing Record 12 of Set 6 | north bend
# Processing Record 13 of Set 6 | molteno
# Processing Record 14 of Set 6 | iqaluit
# Processing Record 15 of Set 6 | cristuru secuiesc
# Processing Record 16 of Set 6 | havre-saint-pierre
# Processing Record 17 of Set 6 | kysyl-syr
# Processing Record 18 of Set 6 | pula
# Processing Record 19 of Set 6 | pevek
# Processing Record 20 of Set 6 | beira
# Processing Record 21 of Set 6 | bambanglipuro
# Processing Record 22 of Set 6 | sechura
# Processing Record 23 of Set 6 | prachuap khiri khan
# Processing Record 24 of Set 6 | severnoye
# Processing Record 25 of Set 6 | gari
# Processing Record 26 of Set 6 | yelizavetino
# Processing Record 27 of Set 6 | comodoro rivadavia
# Processing Record 28 of Set 6 | hami
# Processing Record 29 of Set 6 | batagay
# Processing Record 30 of Set 6 | eyrarbakki
# Processing Record 31 of Set 6 | the valley
# Processing Record 32 of Set 6 | nioro
# Processing Record 33 of Set 6 | qibili
# City not found. Skipping...
# Processing Record 34 of Set 6 | puquio
# Processing Record 35 of Set 6 | tabou
# Processing Record 36 of Set 6 | adrar
# Processing Record 37 of Set 6 | agropoli
# Processing Record 38 of Set 6 | imbituba
# Processing Record 39 of Set 6 | kahului
# Processing Record 40 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 41 of Set 6 | sitka
# Processing Record 42 of Set 6 | popondetta
# Processing Record 43 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 44 of Set 6 | great yarmouth
# Processing Record 45 of Set 6 | korla
# Processing Record 46 of Set 6 | katsuura
# Processing Record 47 of Set 6 | rosita
# Processing Record 48 of Set 6 | deputatskiy
# Processing Record 49 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 50 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 7 | sioux lookout
# Processing Record 2 of Set 7 | miquelon
# Processing Record 3 of Set 7 | sobolevo
# Processing Record 4 of Set 7 | pangkalanbuun
# Processing Record 5 of Set 7 | caucaia
# Processing Record 6 of Set 7 | tanabe
# Processing Record 7 of Set 7 | yar-sale
# Processing Record 8 of Set 7 | pemberton
# Processing Record 9 of Set 7 | oranjemund
# Processing Record 10 of Set 7 | cherdyn
# Processing Record 11 of Set 7 | port hardy
# Processing Record 12 of Set 7 | kavieng
# Processing Record 13 of Set 7 | tyukhtet
# Processing Record 14 of Set 7 | puerto ayacucho
# Processing Record 15 of Set 7 | geraldton
# Processing Record 16 of Set 7 | smithers
# Processing Record 17 of Set 7 | inhambane
# Processing Record 18 of Set 7 | inongo
# Processing Record 19 of Set 7 | tasiilaq
# Processing Record 20 of Set 7 | luderitz
# Processing Record 21 of Set 7 | georgetown
# Processing Record 22 of Set 7 | lazaro cardenas
# Processing Record 23 of Set 7 | matay
# Processing Record 24 of Set 7 | saint george
# Processing Record 25 of Set 7 | salacgriva
# Processing Record 26 of Set 7 | zimmi
# Processing Record 27 of Set 7 | dingle
# Processing Record 28 of Set 7 | codrington
# Processing Record 29 of Set 7 | mahibadhoo
# Processing Record 30 of Set 7 | guane
# Processing Record 31 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 7 | nisia floresta
# Processing Record 33 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 34 of Set 7 | platteville
# Processing Record 35 of Set 7 | flinders
# Processing Record 36 of Set 7 | vila franca do campo
# Processing Record 37 of Set 7 | honningsvag
# Processing Record 38 of Set 7 | inuvik
# Processing Record 39 of Set 7 | thompson
# Processing Record 40 of Set 7 | redcliffe
# Processing Record 41 of Set 7 | eten
# Processing Record 42 of Set 7 | kloulklubed
# Processing Record 43 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 7 | aktau
# Processing Record 45 of Set 7 | tiarei
# Processing Record 46 of Set 7 | dawei
# Processing Record 47 of Set 7 | muscat
# Processing Record 48 of Set 7 | pokhara
# Processing Record 49 of Set 7 | quatre cocos
# Processing Record 50 of Set 7 | wakkanai
# Processing Record 1 of Set 8 | kamaishi
# Processing Record 2 of Set 8 | kangaatsiaq
# Processing Record 3 of Set 8 | eldama ravine
# Processing Record 4 of Set 8 | hay river
# Processing Record 5 of Set 8 | tiksi
# Processing Record 6 of Set 8 | mandalgovi
# Processing Record 7 of Set 8 | puerto el triunfo
# Processing Record 8 of Set 8 | klaksvik
# Processing Record 9 of Set 8 | paamiut
# Processing Record 10 of Set 8 | port-gentil
# Processing Record 11 of Set 8 | forio
# Processing Record 12 of Set 8 | bocana de paiwas
# Processing Record 13 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 8 | provideniya
# Processing Record 15 of Set 8 | wanning
# Processing Record 16 of Set 8 | bourail
# Processing Record 17 of Set 8 | mehamn
# Processing Record 18 of Set 8 | port shepstone
# Processing Record 19 of Set 8 | palana
# Processing Record 20 of Set 8 | nemuro
# Processing Record 21 of Set 8 | guerrero negro
# Processing Record 22 of Set 8 | vardo
# Processing Record 23 of Set 8 | kaeo
# Processing Record 24 of Set 8 | eyl
# Processing Record 25 of Set 8 | hoquiam
# Processing Record 26 of Set 8 | fontem
# Processing Record 27 of Set 8 | ambilobe
# Processing Record 28 of Set 8 | jacqueville
# Processing Record 29 of Set 8 | oranjestad
# Processing Record 30 of Set 8 | carman
# Processing Record 31 of Set 8 | san juan del sur
# Processing Record 32 of Set 8 | holguin
# Processing Record 33 of Set 8 | ust-tsilma
# Processing Record 34 of Set 8 | ponta delgada
# Processing Record 35 of Set 8 | cabanas
# Processing Record 36 of Set 8 | nhulunbuy
# Processing Record 37 of Set 8 | casino
# Processing Record 38 of Set 8 | mezhdurechensk
# Processing Record 39 of Set 8 | ternate
# Processing Record 40 of Set 8 | karera
# Processing Record 41 of Set 8 | sahuaripa
# Processing Record 42 of Set 8 | rio gallegos
# Processing Record 43 of Set 8 | cuiaba
# Processing Record 44 of Set 8 | bakchar
# Processing Record 45 of Set 8 | pedregulho
# Processing Record 46 of Set 8 | olinda
# Processing Record 47 of Set 8 | teruel
# Processing Record 48 of Set 8 | avera
# Processing Record 49 of Set 8 | kattivakkam
# Processing Record 50 of Set 8 | lagoa
# Processing Record 1 of Set 9 | cintalapa
# Processing Record 2 of Set 9 | dunedin
# Processing Record 3 of Set 9 | shache
# Processing Record 4 of Set 9 | brzesko
# Processing Record 5 of Set 9 | avila
# Processing Record 6 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 9 | leningradskiy
# Processing Record 8 of Set 9 | morondava
# Processing Record 9 of Set 9 | beloha
# Processing Record 10 of Set 9 | faya
# Processing Record 11 of Set 9 | caravelas
# Processing Record 12 of Set 9 | monrovia
# Processing Record 13 of Set 9 | paoua
# Processing Record 14 of Set 9 | ranong
# Processing Record 15 of Set 9 | prince rupert
# Processing Record 16 of Set 9 | mayo
# Processing Record 17 of Set 9 | omboue
# Processing Record 18 of Set 9 | mackenzie
# Processing Record 19 of Set 9 | strezhevoy
# Processing Record 20 of Set 9 | sri aman
# Processing Record 21 of Set 9 | anloga
# Processing Record 22 of Set 9 | karratha
# Processing Record 23 of Set 9 | tiznit
# Processing Record 24 of Set 9 | kodiak
# Processing Record 25 of Set 9 | keningau
# Processing Record 26 of Set 9 | krasnoselkup
# Processing Record 27 of Set 9 | bertoua
# Processing Record 28 of Set 9 | makat
# Processing Record 29 of Set 9 | vzmorye
# Processing Record 30 of Set 9 | jinchang
# Processing Record 31 of Set 9 | oistins
# Processing Record 32 of Set 9 | ambovombe
# Processing Record 33 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 9 | mandi
# Processing Record 35 of Set 9 | nanortalik
# Processing Record 36 of Set 9 | port blair
# Processing Record 37 of Set 9 | novoagansk
# Processing Record 38 of Set 9 | derzhavinsk
# Processing Record 39 of Set 9 | quelimane
# Processing Record 40 of Set 9 | tezu
# Processing Record 41 of Set 9 | udachnyy
# Processing Record 42 of Set 9 | brae
# Processing Record 43 of Set 9 | narsaq
# Processing Record 44 of Set 9 | puerto escondido
# Processing Record 45 of Set 9 | bereznik
# Processing Record 46 of Set 9 | plettenberg bay
# Processing Record 47 of Set 9 | manokwari
# Processing Record 48 of Set 9 | east massapequa
# Processing Record 49 of Set 9 | vila velha
# Processing Record 50 of Set 9 | voznesenskoye
# Processing Record 1 of Set 10 | lossiemouth
# Processing Record 2 of Set 10 | sol-iletsk
# Processing Record 3 of Set 10 | trincomalee
# Processing Record 4 of Set 10 | baiquan
# Processing Record 5 of Set 10 | urengoy
# Processing Record 6 of Set 10 | loubomo
# Processing Record 7 of Set 10 | santa rosa
# Processing Record 8 of Set 10 | san vicente
# Processing Record 9 of Set 10 | uvat
# Processing Record 10 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 11 of Set 10 | hamilton
# Processing Record 12 of Set 10 | liverpool
# Processing Record 13 of Set 10 | cabra
# Processing Record 14 of Set 10 | kem
# Processing Record 15 of Set 10 | palembang
# Processing Record 16 of Set 10 | tessalit
# Processing Record 17 of Set 10 | aklavik
# Processing Record 18 of Set 10 | krasnorechenskiy
# Processing Record 19 of Set 10 | bayshore gardens
# Processing Record 20 of Set 10 | alice springs
# Processing Record 21 of Set 10 | namibe
# Processing Record 22 of Set 10 | bilma
# Processing Record 23 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 10 | port hedland
# Processing Record 25 of Set 10 | novyy urengoy
# Processing Record 26 of Set 10 | bida
# Processing Record 27 of Set 10 | marsabit
# Processing Record 28 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 10 | killybegs
# Processing Record 30 of Set 10 | soyo
# Processing Record 31 of Set 10 | nizwa
# Processing Record 32 of Set 10 | dombarovskiy
# Processing Record 33 of Set 10 | sudak
# Processing Record 34 of Set 10 | takoradi
# Processing Record 35 of Set 10 | rosia de secas
# Processing Record 36 of Set 10 | oktyabrskiy
# Processing Record 37 of Set 10 | sur
# Processing Record 38 of Set 10 | abu dhabi
# Processing Record 39 of Set 10 | gidam
# Processing Record 40 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 41 of Set 10 | panguna
# Processing Record 42 of Set 10 | hailar
# Processing Record 43 of Set 10 | san felipe
# Processing Record 44 of Set 10 | el wasta
# City not found. Skipping...
# Processing Record 45 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 10 | jaguey grande
# Processing Record 47 of Set 10 | port macquarie
# Processing Record 48 of Set 10 | bahia honda
# Processing Record 49 of Set 10 | ubinskoye
# Processing Record 50 of Set 10 | owando
# Processing Record 1 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 11 | deder
# Processing Record 3 of Set 11 | mega
# Processing Record 4 of Set 11 | coahuayana
# Processing Record 5 of Set 11 | ambon
# Processing Record 6 of Set 11 | santa isabel
# Processing Record 7 of Set 11 | mount gambier
# Processing Record 8 of Set 11 | kutum
# Processing Record 9 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 11 | harper
# Processing Record 11 of Set 11 | benjamin aceval
# Processing Record 12 of Set 11 | luau
# Processing Record 13 of Set 11 | chickasha
# Processing Record 14 of Set 11 | artvin
# Processing Record 15 of Set 11 | byron bay
# Processing Record 16 of Set 11 | dongsheng
# Processing Record 17 of Set 11 | aktash
# Processing Record 18 of Set 11 | beaupre
# Processing Record 19 of Set 11 | berlevag
# Processing Record 20 of Set 11 | evensk
# Processing Record 21 of Set 11 | wainwright
# Processing Record 22 of Set 11 | sume
# Processing Record 23 of Set 11 | dubbo
# Processing Record 24 of Set 11 | ambulu
# Processing Record 25 of Set 11 | witu
# Processing Record 26 of Set 11 | lata
# Processing Record 27 of Set 11 | usinsk
# Processing Record 28 of Set 11 | stornoway
# Processing Record 29 of Set 11 | gardanne
# Processing Record 30 of Set 11 | westport
# Processing Record 31 of Set 11 | idah
# Processing Record 32 of Set 11 | ostrowiec swietokrzyski
# Processing Record 33 of Set 11 | cocentaina
# Processing Record 34 of Set 11 | camacha
# Processing Record 35 of Set 11 | bambous virieux
# Processing Record 36 of Set 11 | shanting
# Processing Record 37 of Set 11 | bowen
# Processing Record 38 of Set 11 | kudahuvadhoo
# Processing Record 39 of Set 11 | siemianowice slaskie
# Processing Record 40 of Set 11 | mattoon
# Processing Record 41 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 42 of Set 11 | vestbygda
# City not found. Skipping...
# Processing Record 43 of Set 11 | severobaykalsk
# Processing Record 44 of Set 11 | juba
# Processing Record 45 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 46 of Set 11 | erdenet
# Processing Record 47 of Set 11 | ozinki
# Processing Record 48 of Set 11 | mezen
# Processing Record 49 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 11 | el faiyum
# City not found. Skipping...
# Processing Record 1 of Set 12 | correntina
# Processing Record 2 of Set 12 | muros
# Processing Record 3 of Set 12 | pecos
# Processing Record 4 of Set 12 | carutapera
# Processing Record 5 of Set 12 | zemio
# Processing Record 6 of Set 12 | zimapan
# Processing Record 7 of Set 12 | vrangel
# Processing Record 8 of Set 12 | iralaya
# Processing Record 9 of Set 12 | singaraja
# Processing Record 10 of Set 12 | fare
# Processing Record 11 of Set 12 | grand forks
# Processing Record 12 of Set 12 | samfya
# Processing Record 13 of Set 12 | perleberg
# Processing Record 14 of Set 12 | big rapids
# Processing Record 15 of Set 12 | sawakin
# Processing Record 16 of Set 12 | sarh
# Processing Record 17 of Set 12 | pangnirtung
# Processing Record 18 of Set 12 | marawi
# Processing Record 19 of Set 12 | wajima
# Processing Record 20 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 12 | baghdad
# Processing Record 22 of Set 12 | alyangula
# Processing Record 23 of Set 12 | arman
# Processing Record 24 of Set 12 | conceicao da barra
# Processing Record 25 of Set 12 | bremervorde
# Processing Record 26 of Set 12 | qandala
# Processing Record 27 of Set 12 | padang
# Processing Record 28 of Set 12 | bela
# Processing Record 29 of Set 12 | salekhard
# Processing Record 30 of Set 12 | sistranda
# Processing Record 31 of Set 12 | sao filipe
# Processing Record 32 of Set 12 | guican
# Processing Record 33 of Set 12 | tallahassee
# Processing Record 34 of Set 12 | nouadhibou
# Processing Record 35 of Set 12 | senmonorom
# City not found. Skipping...
# Processing Record 36 of Set 12 | margate
# Processing Record 37 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 12 | maua
# Processing Record 39 of Set 12 | sinnamary
# Processing Record 40 of Set 12 | egvekinot
# Processing Record 41 of Set 12 | terrace bay
# Processing Record 42 of Set 12 | lundazi
# Processing Record 43 of Set 12 | nuuk
# Processing Record 44 of Set 12 | kibakwe
# Processing Record 45 of Set 12 | lubango
# Processing Record 46 of Set 12 | punta alta
# Processing Record 47 of Set 12 | lorengau
# Processing Record 48 of Set 12 | bowmore
# Processing Record 49 of Set 12 | tautira
# Processing Record 50 of Set 12 | acarau
# Processing Record 1 of Set 13 | gore
# Processing Record 2 of Set 13 | mount isa
# Processing Record 3 of Set 13 | kabalo
# Processing Record 4 of Set 13 | rebrikha
# Processing Record 5 of Set 13 | rapid valley
# Processing Record 6 of Set 13 | grootfontein
# Processing Record 7 of Set 13 | rawlins
# Processing Record 8 of Set 13 | denpasar
# Processing Record 9 of Set 13 | anadyr
# Processing Record 10 of Set 13 | inirida
# Processing Record 11 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 13 | bonavista
# Processing Record 13 of Set 13 | alugan
# Processing Record 14 of Set 13 | goderich
# Processing Record 15 of Set 13 | erzin
# Processing Record 16 of Set 13 | rize
# Processing Record 17 of Set 13 | mitchelstown
# Processing Record 18 of Set 13 | kenai
# Processing Record 19 of Set 13 | yaguajay
# Processing Record 20 of Set 13 | honiara
# Processing Record 21 of Set 13 | komsomolskiy
# Processing Record 22 of Set 13 | skelleftea
# Processing Record 23 of Set 13 | murray bridge
# Processing Record 24 of Set 13 | jiroft
# City not found. Skipping...
# Processing Record 25 of Set 13 | tocopilla
# Processing Record 26 of Set 13 | iranshahr
# Processing Record 27 of Set 13 | hirara
# Processing Record 28 of Set 13 | nybro
# Processing Record 29 of Set 13 | volchikha
# Processing Record 30 of Set 13 | nuevo progreso
# Processing Record 31 of Set 13 | boulder
# Processing Record 32 of Set 13 | villaviciosa
# Processing Record 33 of Set 13 | manadhoo
# Processing Record 34 of Set 13 | athboy
# Processing Record 35 of Set 13 | zhenlai
# Processing Record 36 of Set 13 | biak
# Processing Record 37 of Set 13 | rantepao
# Processing Record 38 of Set 13 | nakamura
# Processing Record 39 of Set 13 | burica
# City not found. Skipping...
# Processing Record 40 of Set 13 | khash
# Processing Record 41 of Set 13 | matamoros
# Processing Record 42 of Set 13 | sambava
# Processing Record 43 of Set 13 | sao gabriel da cachoeira
# Processing Record 44 of Set 13 | svetlyy
# Processing Record 45 of Set 13 | purpe
# Processing Record 46 of Set 13 | baruun-urt
# Processing Record 47 of Set 13 | aksha
# Processing Record 48 of Set 13 | urbano santos
# Processing Record 49 of Set 13 | hervey bay
# Processing Record 50 of Set 13 | mujiayingzi
# Processing Record 1 of Set 14 | pacific grove
# Processing Record 2 of Set 14 | nakhon thai
# Processing Record 3 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 4 of Set 14 | baiyin
# Processing Record 5 of Set 14 | zyryanka
# Processing Record 6 of Set 14 | mattru
# Processing Record 7 of Set 14 | berdsk
# Processing Record 8 of Set 14 | vesele
# Processing Record 9 of Set 14 | floro
# Processing Record 10 of Set 14 | puerto colombia
# Processing Record 11 of Set 14 | camacupa
# Processing Record 12 of Set 14 | hambantota
# Processing Record 13 of Set 14 | veraval
# Processing Record 14 of Set 14 | abu kamal
# Processing Record 15 of Set 14 | assare
# Processing Record 16 of Set 14 | male
# Processing Record 17 of Set 14 | tokyo
# Processing Record 18 of Set 14 | illapel
# Processing Record 19 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 20 of Set 14 | roma
# Processing Record 21 of Set 14 | altamira
# Processing Record 22 of Set 14 | la ronge
# Processing Record 23 of Set 14 | ola
# Processing Record 24 of Set 14 | birao
# Processing Record 25 of Set 14 | gawler
# Processing Record 26 of Set 14 | turukhansk
# Processing Record 27 of Set 14 | sao felix do xingu
# Processing Record 28 of Set 14 | santa cruz
# Processing Record 29 of Set 14 | kayerkan
# Processing Record 30 of Set 14 | acari
# Processing Record 31 of Set 14 | opuwo
# Processing Record 32 of Set 14 | contai
# Processing Record 33 of Set 14 | nanfeng
# Processing Record 34 of Set 14 | yingcheng
# Processing Record 35 of Set 14 | laguna
# Processing Record 36 of Set 14 | nishihara
# Processing Record 37 of Set 14 | coulihaut
# City not found. Skipping...
# Processing Record 38 of Set 14 | iskateley
# Processing Record 39 of Set 14 | kodinsk
# Processing Record 40 of Set 14 | kuala terengganu
# Processing Record 41 of Set 14 | penzance
# Processing Record 42 of Set 14 | roald
# Processing Record 43 of Set 14 | mareeba
# Processing Record 44 of Set 14 | eirunepe
# Processing Record 45 of Set 14 | schermbeck
# Processing Record 46 of Set 14 | ankang
# Processing Record 47 of Set 14 | guymon
# Processing Record 48 of Set 14 | sawai madhopur
# Processing Record 49 of Set 14 | pampa
# Processing Record 50 of Set 14 | seoul
# Processing Record 1 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 15 | hvide sande
# Processing Record 3 of Set 15 | betare oya
# Processing Record 4 of Set 15 | adre
# Processing Record 5 of Set 15 | garissa
# Processing Record 6 of Set 15 | changli
# Processing Record 7 of Set 15 | magadi
# Processing Record 8 of Set 15 | nizhnevartovsk
# Processing Record 9 of Set 15 | mazagao
# Processing Record 10 of Set 15 | cay
# Processing Record 11 of Set 15 | kieta
# Processing Record 12 of Set 15 | san martin
# Processing Record 13 of Set 15 | fuerte olimpo
# Processing Record 14 of Set 15 | baykit
# Processing Record 15 of Set 15 | kenora
# Processing Record 16 of Set 15 | perth
# Processing Record 17 of Set 15 | coari
# Processing Record 18 of Set 15 | jasper
# Processing Record 19 of Set 15 | fortuna
# Processing Record 20 of Set 15 | itarema
# Processing Record 21 of Set 15 | kibala
# Processing Record 22 of Set 15 | listowel
# Processing Record 23 of Set 15 | bend
# Processing Record 24 of Set 15 | yankton
# Processing Record 25 of Set 15 | bulgan
# Processing Record 26 of Set 15 | manhattan
# Processing Record 27 of Set 15 | salinopolis
# Processing Record 28 of Set 15 | kibondo
# Processing Record 29 of Set 15 | mecca
# Processing Record 30 of Set 15 | vanimo
# Processing Record 31 of Set 15 | vila do maio
# Processing Record 32 of Set 15 | meadow lake
# Processing Record 33 of Set 15 | fairbanks
# Processing Record 34 of Set 15 | chicama
# Processing Record 35 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 15 | alma
# Processing Record 37 of Set 15 | aitape
# Processing Record 38 of Set 15 | boende
# Processing Record 39 of Set 15 | cap malheureux
# Processing Record 40 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 15 | yongan
# Processing Record 42 of Set 15 | piacabucu
# Processing Record 43 of Set 15 | isiro
# Processing Record 44 of Set 15 | aripuana
# Processing Record 45 of Set 15 | show low
# Processing Record 46 of Set 15 | mackay
# Processing Record 47 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 15 | miyako
# Processing Record 49 of Set 15 | sola
# Processing Record 50 of Set 15 | okha
# Processing Record 1 of Set 16 | zabid
# Processing Record 2 of Set 16 | gao
# Processing Record 3 of Set 16 | tual
# Processing Record 4 of Set 16 | sungaipenuh
# Processing Record 5 of Set 16 | la roche-sur-yon
# Processing Record 6 of Set 16 | coruripe
# Processing Record 7 of Set 16 | liaoyang
# Processing Record 8 of Set 16 | panjab
# Processing Record 9 of Set 16 | virginia beach
# Processing Record 10 of Set 16 | rudnogorsk
# Processing Record 11 of Set 16 | novyy kostek
# Processing Record 12 of Set 16 | yafran
# Processing Record 13 of Set 16 | eureka
# Processing Record 14 of Set 16 | jiddah
# City not found. Skipping...
# Processing Record 15 of Set 16 | ca mau
# Processing Record 16 of Set 16 | hegang
# Processing Record 17 of Set 16 | northam
# Processing Record 18 of Set 16 | voyvozh
# Processing Record 19 of Set 16 | roura
# Processing Record 20 of Set 16 | axim
# Processing Record 21 of Set 16 | vestmannaeyjar
# Processing Record 22 of Set 16 | saint-augustin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 712

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Chapais  49.7834  -74.8492      9.88        99         100
# 1         Airai  -8.9266  125.4092     23.05        63          82
# 2        Atuona  -9.8000 -139.0333     24.91        69          40
# 3     Busselton -33.6500  115.3333     14.21        69          58
# 4   Port Alfred -33.5906   26.8910     15.10        90           0
# 5  Punta Arenas -53.1500  -70.9167      7.06        76          75
# 6   Yellowknife  62.4560 -114.3525      2.29        64          75
# 7         Bluff -46.6000  168.3333      4.33        68          94
# 8       Edremit  39.5961   27.0244     13.86        72           0
# 9       Rikitea -23.1203 -134.9692     21.44        61          77
#
#    Wind Speed Country Current Description
# 0        1.35      CA     overcast clouds
# 1        0.97      TL       broken clouds
# 2        9.31      PF    scattered clouds
# 3        7.83      AU       broken clouds
# 4        0.45      ZA           clear sky
# 5        3.60      CL       broken clouds
# 6        5.66      CA       broken clouds
# 7       13.79      NZ     overcast clouds
# 8        4.12      TR           clear sky
# 9       10.79      PF       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Chapais      CA  49.7834  -74.8492      9.88        99         100
# 1         Airai      TL  -8.9266  125.4092     23.05        63          82
# 2        Atuona      PF  -9.8000 -139.0333     24.91        69          40
# 3     Busselton      AU -33.6500  115.3333     14.21        69          58
# 4   Port Alfred      ZA -33.5906   26.8910     15.10        90           0
# 5  Punta Arenas      CL -53.1500  -70.9167      7.06        76          75
# 6   Yellowknife      CA  62.4560 -114.3525      2.29        64          75
# 7         Bluff      NZ -46.6000  168.3333      4.33        68          94
# 8       Edremit      TR  39.5961   27.0244     13.86        72           0
# 9       Rikitea      PF -23.1203 -134.9692     21.44        61          77
#
#    Wind Speed Current Description
# 0        1.35     overcast clouds
# 1        0.97       broken clouds
# 2        9.31    scattered clouds
# 3        7.83       broken clouds
# 4        0.45           clear sky
# 5        3.60       broken clouds
# 6        5.66       broken clouds
# 7       13.79     overcast clouds
# 8        4.12           clear sky
# 9       10.79       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
