# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
# Size set to 20 to limit API calls. Once everything is finished, change 10 to 2000
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 763

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?"

city_url = f"{url}&q={city}&appid={weather_api_key}&units=imperial"
#city_url = url + "&q=" + city.replace(" ","+") + "&appid=" + weather_api_key + "&units=imperial"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?&q=hithadhoo&appid=497c45a5a89fff05c0f388528e0cc402&units=imperial

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
print(city_weather)
# Out:
# <Response [200]>

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+") + "&appid=" + weather_api_key + "&units=imperial"
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | port lincoln
# Processing Record 3 of Set 1 | kenai
# Processing Record 4 of Set 1 | suoyarvi
# Processing Record 5 of Set 1 | canutama
# Processing Record 6 of Set 1 | kruisfontein
# Processing Record 7 of Set 1 | tabuk
# Processing Record 8 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | pachino
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | uyemskiy
# Processing Record 19 of Set 1 | port blair
# Processing Record 20 of Set 1 | fomboni
# Processing Record 21 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | chegutu
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | wanganui
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | alyangula
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | necochea
# Processing Record 31 of Set 1 | huarmey
# Processing Record 32 of Set 1 | fort saint john
# City not found. Skipping...
# Processing Record 33 of Set 1 | uryupinsk
# Processing Record 34 of Set 1 | severo-kurilsk
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 1 | hambantota
# Processing Record 39 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 1 | salalah
# Processing Record 41 of Set 1 | shimoda
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | ponca city
# Processing Record 44 of Set 1 | lagoa
# Processing Record 45 of Set 1 | kawana waters
# City not found. Skipping...
# Processing Record 46 of Set 1 | zlitan
# Processing Record 47 of Set 1 | praia da vitoria
# Processing Record 48 of Set 1 | chuy
# Processing Record 49 of Set 1 | sawakin
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | kembe
# Processing Record 4 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | saint-joseph
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | lata
# Processing Record 11 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 2 | pontianak
# Processing Record 13 of Set 2 | sao filipe
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | pahasu
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | codrington
# Processing Record 20 of Set 2 | songjianghe
# Processing Record 21 of Set 2 | victoria
# Processing Record 22 of Set 2 | maceio
# Processing Record 23 of Set 2 | bud
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | marienburg
# Processing Record 26 of Set 2 | oranjemund
# Processing Record 27 of Set 2 | khasan
# Processing Record 28 of Set 2 | mackenzie
# Processing Record 29 of Set 2 | tasiilaq
# Processing Record 30 of Set 2 | pevek
# Processing Record 31 of Set 2 | lishan
# Processing Record 32 of Set 2 | banmo
# City not found. Skipping...
# Processing Record 33 of Set 2 | ostrovnoy
# Processing Record 34 of Set 2 | kodiak
# Processing Record 35 of Set 2 | mwinilunga
# Processing Record 36 of Set 2 | villarrica
# Processing Record 37 of Set 2 | preeceville
# Processing Record 38 of Set 2 | brae
# Processing Record 39 of Set 2 | bonavista
# Processing Record 40 of Set 2 | port elizabeth
# Processing Record 41 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 2 | ketchikan
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 2 | butaritari
# Processing Record 46 of Set 2 | bahia honda
# Processing Record 47 of Set 2 | santa rosa
# Processing Record 48 of Set 2 | warrington
# Processing Record 49 of Set 2 | pochutla
# Processing Record 50 of Set 2 | sao joao da barra
# Processing Record 1 of Set 3 | busselton
# Processing Record 2 of Set 3 | shuyskoye
# Processing Record 3 of Set 3 | luderitz
# Processing Record 4 of Set 3 | ushirombo
# Processing Record 5 of Set 3 | tiarei
# Processing Record 6 of Set 3 | pisco
# Processing Record 7 of Set 3 | simonesti
# Processing Record 8 of Set 3 | ellisras
# Processing Record 9 of Set 3 | grand gaube
# Processing Record 10 of Set 3 | sawtell
# Processing Record 11 of Set 3 | jining
# Processing Record 12 of Set 3 | chokurdakh
# Processing Record 13 of Set 3 | bredasdorp
# Processing Record 14 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 15 of Set 3 | kungurtug
# Processing Record 16 of Set 3 | itaqui
# Processing Record 17 of Set 3 | vardo
# Processing Record 18 of Set 3 | otacilio costa
# Processing Record 19 of Set 3 | yeppoon
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | collie
# Processing Record 22 of Set 3 | chutove
# Processing Record 23 of Set 3 | ixtapa
# Processing Record 24 of Set 3 | hovd
# Processing Record 25 of Set 3 | nome
# Processing Record 26 of Set 3 | hamilton
# Processing Record 27 of Set 3 | havelock
# Processing Record 28 of Set 3 | makinsk
# Processing Record 29 of Set 3 | aykhal
# Processing Record 30 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 3 | kristiansund
# Processing Record 32 of Set 3 | dzaoudzi
# Processing Record 33 of Set 3 | hirara
# Processing Record 34 of Set 3 | martigues
# Processing Record 35 of Set 3 | olafsvik
# Processing Record 36 of Set 3 | thaba nchu
# Processing Record 37 of Set 3 | amuntai
# Processing Record 38 of Set 3 | were ilu
# Processing Record 39 of Set 3 | bambous virieux
# Processing Record 40 of Set 3 | gazanjyk
# Processing Record 41 of Set 3 | atagay
# Processing Record 42 of Set 3 | ahipara
# Processing Record 43 of Set 3 | wewak
# Processing Record 44 of Set 3 | airai
# Processing Record 45 of Set 3 | prnjavor
# Processing Record 46 of Set 3 | lebu
# Processing Record 47 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 3 | norman wells
# Processing Record 49 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 3 | ilulissat
# Processing Record 1 of Set 4 | lavrentiya
# Processing Record 2 of Set 4 | roma
# Processing Record 3 of Set 4 | kahului
# Processing Record 4 of Set 4 | souillac
# Processing Record 5 of Set 4 | buraydah
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | dwarka
# Processing Record 8 of Set 4 | isiro
# Processing Record 9 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 10 of Set 4 | wajima
# Processing Record 11 of Set 4 | atuona
# Processing Record 12 of Set 4 | miri
# Processing Record 13 of Set 4 | vostok
# Processing Record 14 of Set 4 | te anau
# Processing Record 15 of Set 4 | vestmannaeyjar
# Processing Record 16 of Set 4 | kizema
# Processing Record 17 of Set 4 | rincon
# Processing Record 18 of Set 4 | svetlaya
# Processing Record 19 of Set 4 | jutai
# Processing Record 20 of Set 4 | ixtepec
# Processing Record 21 of Set 4 | ponta do sol
# Processing Record 22 of Set 4 | klaksvik
# Processing Record 23 of Set 4 | da nang
# Processing Record 24 of Set 4 | poum
# Processing Record 25 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 4 | dingle
# Processing Record 27 of Set 4 | saint-pierre
# Processing Record 28 of Set 4 | fairbanks
# Processing Record 29 of Set 4 | provideniya
# Processing Record 30 of Set 4 | copacabana
# Processing Record 31 of Set 4 | doha
# Processing Record 32 of Set 4 | kozhva
# Processing Record 33 of Set 4 | shu
# Processing Record 34 of Set 4 | faanui
# Processing Record 35 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 36 of Set 4 | veraval
# Processing Record 37 of Set 4 | aracati
# Processing Record 38 of Set 4 | cockburn town
# Processing Record 39 of Set 4 | beinamar
# Processing Record 40 of Set 4 | lompoc
# Processing Record 41 of Set 4 | shubarkuduk
# Processing Record 42 of Set 4 | linhares
# Processing Record 43 of Set 4 | zhob
# Processing Record 44 of Set 4 | upernavik
# Processing Record 45 of Set 4 | verkhoyansk
# Processing Record 46 of Set 4 | cayenne
# Processing Record 47 of Set 4 | ribeira grande
# Processing Record 48 of Set 4 | khatanga
# Processing Record 49 of Set 4 | katsuura
# Processing Record 50 of Set 4 | ancud
# Processing Record 1 of Set 5 | castro
# Processing Record 2 of Set 5 | saldanha
# Processing Record 3 of Set 5 | torbay
# Processing Record 4 of Set 5 | namatanai
# Processing Record 5 of Set 5 | sitka
# Processing Record 6 of Set 5 | la libertad
# Processing Record 7 of Set 5 | araouane
# Processing Record 8 of Set 5 | carnarvon
# Processing Record 9 of Set 5 | abu jubayhah
# City not found. Skipping...
# Processing Record 10 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 11 of Set 5 | mantua
# Processing Record 12 of Set 5 | katumba
# Processing Record 13 of Set 5 | pacifica
# Processing Record 14 of Set 5 | qasigiannguit
# Processing Record 15 of Set 5 | neiafu
# Processing Record 16 of Set 5 | pangnirtung
# Processing Record 17 of Set 5 | mayo
# Processing Record 18 of Set 5 | flinders
# Processing Record 19 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 5 | hasaki
# Processing Record 21 of Set 5 | mezen
# Processing Record 22 of Set 5 | dongning
# Processing Record 23 of Set 5 | boone
# Processing Record 24 of Set 5 | san quintin
# Processing Record 25 of Set 5 | paamiut
# Processing Record 26 of Set 5 | dologon
# Processing Record 27 of Set 5 | nanortalik
# Processing Record 28 of Set 5 | fortuna
# Processing Record 29 of Set 5 | juba
# Processing Record 30 of Set 5 | mount gambier
# Processing Record 31 of Set 5 | kotka
# Processing Record 32 of Set 5 | waddan
# Processing Record 33 of Set 5 | abha
# Processing Record 34 of Set 5 | russell
# Processing Record 35 of Set 5 | ljubinje
# Processing Record 36 of Set 5 | sept-iles
# Processing Record 37 of Set 5 | beringovskiy
# Processing Record 38 of Set 5 | mar del plata
# Processing Record 39 of Set 5 | newport
# Processing Record 40 of Set 5 | clyde river
# Processing Record 41 of Set 5 | hami
# Processing Record 42 of Set 5 | port-cartier
# Processing Record 43 of Set 5 | utrecht
# Processing Record 44 of Set 5 | selje
# Processing Record 45 of Set 5 | kristinehamn
# Processing Record 46 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 5 | kaitangata
# Processing Record 48 of Set 5 | marawi
# Processing Record 49 of Set 5 | lyuban
# Processing Record 50 of Set 5 | matagami
# Processing Record 1 of Set 6 | kyra
# Processing Record 2 of Set 6 | laguna
# Processing Record 3 of Set 6 | olean
# Processing Record 4 of Set 6 | sumilao
# Processing Record 5 of Set 6 | bethel
# Processing Record 6 of Set 6 | galle
# Processing Record 7 of Set 6 | rio grande
# Processing Record 8 of Set 6 | bereda
# Processing Record 9 of Set 6 | oda
# Processing Record 10 of Set 6 | husavik
# Processing Record 11 of Set 6 | takoradi
# Processing Record 12 of Set 6 | muros
# Processing Record 13 of Set 6 | tiksi
# Processing Record 14 of Set 6 | jishou
# Processing Record 15 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 16 of Set 6 | summerland
# Processing Record 17 of Set 6 | fethiye
# Processing Record 18 of Set 6 | natal
# Processing Record 19 of Set 6 | labuhan
# Processing Record 20 of Set 6 | almaznyy
# Processing Record 21 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 22 of Set 6 | cerrito
# Processing Record 23 of Set 6 | richards bay
# Processing Record 24 of Set 6 | kichera
# Processing Record 25 of Set 6 | grand-santi
# Processing Record 26 of Set 6 | yurimaguas
# Processing Record 27 of Set 6 | byron bay
# Processing Record 28 of Set 6 | saint-paul
# Processing Record 29 of Set 6 | banamba
# Processing Record 30 of Set 6 | ormara
# Processing Record 31 of Set 6 | aanekoski
# Processing Record 32 of Set 6 | college
# Processing Record 33 of Set 6 | nhlangano
# Processing Record 34 of Set 6 | aksehir
# Processing Record 35 of Set 6 | bandar-e lengeh
# Processing Record 36 of Set 6 | tisovec
# Processing Record 37 of Set 6 | tigil
# Processing Record 38 of Set 6 | sulangan
# Processing Record 39 of Set 6 | atikokan
# Processing Record 40 of Set 6 | ulaanbaatar
# Processing Record 41 of Set 6 | penzance
# Processing Record 42 of Set 6 | dudinka
# Processing Record 43 of Set 6 | saint anthony
# Processing Record 44 of Set 6 | aklavik
# Processing Record 45 of Set 6 | jumla
# Processing Record 46 of Set 6 | manta
# Processing Record 47 of Set 6 | belmonte
# Processing Record 48 of Set 6 | brasilia de minas
# Processing Record 49 of Set 6 | trairi
# Processing Record 50 of Set 6 | whitehorse
# Processing Record 1 of Set 7 | komsomolskiy
# Processing Record 2 of Set 7 | wilmington
# Processing Record 3 of Set 7 | yeniseysk
# Processing Record 4 of Set 7 | vieux-habitants
# Processing Record 5 of Set 7 | bengkulu
# Processing Record 6 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 7 of Set 7 | flin flon
# Processing Record 8 of Set 7 | sulphur
# Processing Record 9 of Set 7 | burkhala
# City not found. Skipping...
# Processing Record 10 of Set 7 | margate
# Processing Record 11 of Set 7 | cheyenne
# Processing Record 12 of Set 7 | nara
# Processing Record 13 of Set 7 | geraldton
# Processing Record 14 of Set 7 | saint-orens-de-gameville
# Processing Record 15 of Set 7 | luganville
# Processing Record 16 of Set 7 | jishui
# Processing Record 17 of Set 7 | felanitx
# Processing Record 18 of Set 7 | general roca
# Processing Record 19 of Set 7 | mangrol
# Processing Record 20 of Set 7 | balabac
# Processing Record 21 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 7 | mersing
# Processing Record 23 of Set 7 | zhigansk
# Processing Record 24 of Set 7 | marystown
# Processing Record 25 of Set 7 | taoudenni
# Processing Record 26 of Set 7 | virginia beach
# Processing Record 27 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 28 of Set 7 | zalesovo
# Processing Record 29 of Set 7 | kainantu
# Processing Record 30 of Set 7 | ola
# Processing Record 31 of Set 7 | thompson
# Processing Record 32 of Set 7 | mangai
# Processing Record 33 of Set 7 | inhambane
# Processing Record 34 of Set 7 | izmayil
# Processing Record 35 of Set 7 | at-bashi
# Processing Record 36 of Set 7 | nocupetaro
# Processing Record 37 of Set 7 | hirado
# Processing Record 38 of Set 7 | cocorit
# Processing Record 39 of Set 7 | baherden
# Processing Record 40 of Set 7 | yatou
# Processing Record 41 of Set 7 | bagdarin
# Processing Record 42 of Set 7 | kokopo
# Processing Record 43 of Set 7 | carutapera
# Processing Record 44 of Set 7 | salinopolis
# Processing Record 45 of Set 7 | sorong
# Processing Record 46 of Set 7 | talnakh
# Processing Record 47 of Set 7 | oksfjord
# Processing Record 48 of Set 7 | cabedelo
# Processing Record 49 of Set 7 | vikulovo
# Processing Record 50 of Set 7 | barcelos
# Processing Record 1 of Set 8 | lazaro cardenas
# Processing Record 2 of Set 8 | wenling
# Processing Record 3 of Set 8 | marabba
# Processing Record 4 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 8 | pokosnoye
# Processing Record 6 of Set 8 | shelopugino
# Processing Record 7 of Set 8 | sabang
# Processing Record 8 of Set 8 | port moresby
# Processing Record 9 of Set 8 | sorland
# Processing Record 10 of Set 8 | mosquera
# Processing Record 11 of Set 8 | lixourion
# Processing Record 12 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 8 | porto novo
# Processing Record 14 of Set 8 | marsa matruh
# Processing Record 15 of Set 8 | goderich
# Processing Record 16 of Set 8 | auki
# Processing Record 17 of Set 8 | cherskiy
# Processing Record 18 of Set 8 | butte
# Processing Record 19 of Set 8 | macklin
# Processing Record 20 of Set 8 | koungou
# Processing Record 21 of Set 8 | saint-augustin
# Processing Record 22 of Set 8 | shatoy
# Processing Record 23 of Set 8 | barcelona
# Processing Record 24 of Set 8 | yar-sale
# Processing Record 25 of Set 8 | serenje
# Processing Record 26 of Set 8 | santa cruz
# Processing Record 27 of Set 8 | uzumlu
# City not found. Skipping...
# Processing Record 28 of Set 8 | morden
# Processing Record 29 of Set 8 | hansot
# Processing Record 30 of Set 8 | evensk
# Processing Record 31 of Set 8 | dauphin
# Processing Record 32 of Set 8 | vega baja
# Processing Record 33 of Set 8 | narsaq
# Processing Record 34 of Set 8 | vanimo
# Processing Record 35 of Set 8 | namibe
# Processing Record 36 of Set 8 | shirvan
# Processing Record 37 of Set 8 | nambucca heads
# Processing Record 38 of Set 8 | mgandu
# Processing Record 39 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 8 | half moon bay
# Processing Record 41 of Set 8 | petatlan
# Processing Record 42 of Set 8 | tamandare
# Processing Record 43 of Set 8 | tuatapere
# Processing Record 44 of Set 8 | red bluff
# Processing Record 45 of Set 8 | caruray
# Processing Record 46 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 8 | nanakuli
# Processing Record 48 of Set 8 | kalomo
# City not found. Skipping...
# Processing Record 49 of Set 8 | socorro
# Processing Record 50 of Set 8 | yamada
# Processing Record 1 of Set 9 | kathmandu
# Processing Record 2 of Set 9 | nelson bay
# Processing Record 3 of Set 9 | cooma
# Processing Record 4 of Set 9 | acapulco
# Processing Record 5 of Set 9 | tunduru
# City not found. Skipping...
# Processing Record 6 of Set 9 | egvekinot
# Processing Record 7 of Set 9 | birjand
# Processing Record 8 of Set 9 | khandyga
# Processing Record 9 of Set 9 | mehamn
# Processing Record 10 of Set 9 | lahaina
# Processing Record 11 of Set 9 | schruns
# Processing Record 12 of Set 9 | wakkanai
# Processing Record 13 of Set 9 | mandera
# Processing Record 14 of Set 9 | charters towers
# Processing Record 15 of Set 9 | locri
# Processing Record 16 of Set 9 | neyshabur
# Processing Record 17 of Set 9 | honiara
# Processing Record 18 of Set 9 | west wendover
# Processing Record 19 of Set 9 | interlaken
# Processing Record 20 of Set 9 | dehloran
# Processing Record 21 of Set 9 | guerrero negro
# Processing Record 22 of Set 9 | mitsamiouli
# Processing Record 23 of Set 9 | otuzco
# Processing Record 24 of Set 9 | la asuncion
# Processing Record 25 of Set 9 | bolshoye selo
# Processing Record 26 of Set 9 | koygorodok
# Processing Record 27 of Set 9 | mutis
# Processing Record 28 of Set 9 | port hardy
# Processing Record 29 of Set 9 | chara
# Processing Record 30 of Set 9 | leh
# Processing Record 31 of Set 9 | aksu
# Processing Record 32 of Set 9 | langenburg
# Processing Record 33 of Set 9 | constitucion
# Processing Record 34 of Set 9 | east london
# Processing Record 35 of Set 9 | mount isa
# Processing Record 36 of Set 9 | akyab
# Processing Record 37 of Set 9 | leningradskiy
# Processing Record 38 of Set 9 | hobyo
# Processing Record 39 of Set 9 | dois vizinhos
# Processing Record 40 of Set 9 | krasnogorskoye
# Processing Record 41 of Set 9 | cidreira
# Processing Record 42 of Set 9 | wadi maliz
# Processing Record 43 of Set 9 | bocas del toro
# Processing Record 44 of Set 9 | silvassa
# Processing Record 45 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 46 of Set 9 | alekseyevka
# Processing Record 47 of Set 9 | alice springs
# Processing Record 48 of Set 9 | belozerskoye
# Processing Record 49 of Set 9 | krasnoselkup
# Processing Record 50 of Set 9 | kansanshi
# Processing Record 1 of Set 10 | celestun
# Processing Record 2 of Set 10 | ucluelet
# Processing Record 3 of Set 10 | boguchany
# Processing Record 4 of Set 10 | alamosa
# Processing Record 5 of Set 10 | manjacaze
# Processing Record 6 of Set 10 | juneau
# Processing Record 7 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 10 | gravdal
# Processing Record 9 of Set 10 | yenagoa
# Processing Record 10 of Set 10 | menongue
# Processing Record 11 of Set 10 | tarakan
# Processing Record 12 of Set 10 | sindou
# Processing Record 13 of Set 10 | westport
# Processing Record 14 of Set 10 | teguldet
# Processing Record 15 of Set 10 | vao
# Processing Record 16 of Set 10 | cabo san lucas
# Processing Record 17 of Set 10 | kologriv
# Processing Record 18 of Set 10 | la ronge
# Processing Record 19 of Set 10 | soderhamn
# Processing Record 20 of Set 10 | west point
# Processing Record 21 of Set 10 | chipinge
# Processing Record 22 of Set 10 | tongren
# Processing Record 23 of Set 10 | rocha
# Processing Record 24 of Set 10 | ambon
# Processing Record 25 of Set 10 | fort nelson
# Processing Record 26 of Set 10 | cap malheureux
# Processing Record 27 of Set 10 | bayevo
# Processing Record 28 of Set 10 | dolores hidalgo
# Processing Record 29 of Set 10 | pucallpa
# Processing Record 30 of Set 10 | nouadhibou
# Processing Record 31 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 10 | belmopan
# Processing Record 33 of Set 10 | saint george
# Processing Record 34 of Set 10 | kununurra
# Processing Record 35 of Set 10 | itarema
# Processing Record 36 of Set 10 | mucurici
# Processing Record 37 of Set 10 | xichang
# Processing Record 38 of Set 10 | kieta
# Processing Record 39 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 10 | tailai
# Processing Record 41 of Set 10 | caravelas
# Processing Record 42 of Set 10 | baruun-urt
# Processing Record 43 of Set 10 | mandalgovi
# Processing Record 44 of Set 10 | porto nacional
# Processing Record 45 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 46 of Set 10 | meulaboh
# Processing Record 47 of Set 10 | kaitong
# Processing Record 48 of Set 10 | colac
# Processing Record 49 of Set 10 | gaziantep
# Processing Record 50 of Set 10 | gohana
# Processing Record 1 of Set 11 | oranjestad
# Processing Record 2 of Set 11 | warren
# Processing Record 3 of Set 11 | nikel
# Processing Record 4 of Set 11 | pontes e lacerda
# Processing Record 5 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 6 of Set 11 | bijawar
# Processing Record 7 of Set 11 | acarau
# Processing Record 8 of Set 11 | buala
# Processing Record 9 of Set 11 | samarai
# Processing Record 10 of Set 11 | cam pha
# City not found. Skipping...
# Processing Record 11 of Set 11 | emba
# Processing Record 12 of Set 11 | sicuani
# Processing Record 13 of Set 11 | ambilobe
# Processing Record 14 of Set 11 | venice
# Processing Record 15 of Set 11 | tecoanapa
# Processing Record 16 of Set 11 | suntar
# Processing Record 17 of Set 11 | owase
# Processing Record 18 of Set 11 | zomin
# Processing Record 19 of Set 11 | teguise
# Processing Record 20 of Set 11 | pacific grove
# Processing Record 21 of Set 11 | voyvozh
# Processing Record 22 of Set 11 | touba
# Processing Record 23 of Set 11 | port macquarie
# Processing Record 24 of Set 11 | prince rupert
# Processing Record 25 of Set 11 | binga
# Processing Record 26 of Set 11 | forotic
# Processing Record 27 of Set 11 | villazon
# Processing Record 28 of Set 11 | bachatskiy
# Processing Record 29 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 11 | kijang
# Processing Record 32 of Set 11 | padang
# Processing Record 33 of Set 11 | agadez
# Processing Record 34 of Set 11 | fuerte olimpo
# Processing Record 35 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 11 | manicore
# Processing Record 37 of Set 11 | anadyr
# Processing Record 38 of Set 11 | kavieng
# Processing Record 39 of Set 11 | iqaluit
# Processing Record 40 of Set 11 | urengoy
# Processing Record 41 of Set 11 | abu dhabi
# Processing Record 42 of Set 11 | lumeje
# Processing Record 43 of Set 11 | jujuy
# City not found. Skipping...
# Processing Record 44 of Set 11 | yulara
# Processing Record 45 of Set 11 | atsiki
# City not found. Skipping...
# Processing Record 46 of Set 11 | kalmunai
# Processing Record 47 of Set 11 | orichi
# Processing Record 48 of Set 11 | benidorm
# Processing Record 49 of Set 11 | kerema
# Processing Record 50 of Set 11 | hofn
# Processing Record 1 of Set 12 | christchurch
# Processing Record 2 of Set 12 | surgut
# Processing Record 3 of Set 12 | banda aceh
# Processing Record 4 of Set 12 | iquique
# Processing Record 5 of Set 12 | moindou
# Processing Record 6 of Set 12 | port augusta
# Processing Record 7 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 12 | garissa
# Processing Record 9 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 12 | baghdad
# Processing Record 11 of Set 12 | miles city
# Processing Record 12 of Set 12 | yining
# Processing Record 13 of Set 12 | sur
# Processing Record 14 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 15 of Set 12 | sompeta
# Processing Record 16 of Set 12 | lensk
# Processing Record 17 of Set 12 | remanso
# Processing Record 18 of Set 12 | sungaipenuh
# Processing Record 19 of Set 12 | camacha
# Processing Record 20 of Set 12 | kez
# Processing Record 21 of Set 12 | chapleau
# Processing Record 22 of Set 12 | ust-kuyga
# Processing Record 23 of Set 12 | touros
# Processing Record 24 of Set 12 | manaus
# Processing Record 25 of Set 12 | naze
# Processing Record 26 of Set 12 | vana-vigala
# Processing Record 27 of Set 12 | viedma
# Processing Record 28 of Set 12 | abnub
# Processing Record 29 of Set 12 | itaituba
# Processing Record 30 of Set 12 | batalha
# Processing Record 31 of Set 12 | tokur
# Processing Record 32 of Set 12 | ballina
# Processing Record 33 of Set 12 | hearst
# Processing Record 34 of Set 12 | halifax
# Processing Record 35 of Set 12 | lagos
# Processing Record 36 of Set 12 | batticaloa
# Processing Record 37 of Set 12 | ugoofaaru
# Processing Record 38 of Set 12 | thenzawl
# Processing Record 39 of Set 12 | grindavik
# Processing Record 40 of Set 12 | alofi
# Processing Record 41 of Set 12 | katha
# City not found. Skipping...
# Processing Record 42 of Set 12 | pekan
# Processing Record 43 of Set 12 | galich
# Processing Record 44 of Set 12 | san patricio
# Processing Record 45 of Set 12 | ahar
# Processing Record 46 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 47 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 12 | teya
# Processing Record 49 of Set 12 | akdepe
# Processing Record 50 of Set 12 | dom pedrito
# Processing Record 1 of Set 13 | raga
# Processing Record 2 of Set 13 | avera
# Processing Record 3 of Set 13 | thanh hoa
# Processing Record 4 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 13 | san carlos de bariloche
# Processing Record 6 of Set 13 | roebourne
# Processing Record 7 of Set 13 | tienen
# Processing Record 8 of Set 13 | ranau
# Processing Record 9 of Set 13 | tubuala
# Processing Record 10 of Set 13 | skibbereen
# Processing Record 11 of Set 13 | akdagmadeni
# Processing Record 12 of Set 13 | bilibino
# Processing Record 13 of Set 13 | agropoli
# Processing Record 14 of Set 13 | plouzane
# Processing Record 15 of Set 13 | coquimbo
# Processing Record 16 of Set 13 | kenora
# Processing Record 17 of Set 13 | porbandar
# Processing Record 18 of Set 13 | vryburg
# Processing Record 19 of Set 13 | vila velha
# Processing Record 20 of Set 13 | coihaique
# Processing Record 21 of Set 13 | bathsheba
# Processing Record 22 of Set 13 | vila franca do campo
# Processing Record 23 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 24 of Set 13 | zaykovo
# Processing Record 25 of Set 13 | chama
# Processing Record 26 of Set 13 | elizabeth city
# Processing Record 27 of Set 13 | skjervoy
# Processing Record 28 of Set 13 | tura
# Processing Record 29 of Set 13 | canmore
# Processing Record 30 of Set 13 | ilebo
# Processing Record 31 of Set 13 | los llanos de aridane
# Processing Record 32 of Set 13 | banjar
# Processing Record 33 of Set 13 | kaohsiung
# Processing Record 34 of Set 13 | isangel
# Processing Record 35 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 13 | shache
# Processing Record 37 of Set 13 | zhigalovo
# Processing Record 38 of Set 13 | petropavlovka
# Processing Record 39 of Set 13 | fushun
# Processing Record 40 of Set 13 | antalaha
# Processing Record 41 of Set 13 | puerto maldonado
# Processing Record 42 of Set 13 | qitaihe
# Processing Record 43 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 44 of Set 13 | wukari
# Processing Record 45 of Set 13 | remontnoye
# Processing Record 46 of Set 13 | taltal
# Processing Record 47 of Set 13 | djambala
# Processing Record 48 of Set 13 | libiaz
# Processing Record 49 of Set 13 | maniitsoq
# Processing Record 50 of Set 13 | varca
# Processing Record 1 of Set 14 | kourou
# Processing Record 2 of Set 14 | ponta delgada
# Processing Record 3 of Set 14 | otane
# Processing Record 4 of Set 14 | nerchinskiy zavod
# Processing Record 5 of Set 14 | marsh harbour
# Processing Record 6 of Set 14 | vinh long
# Processing Record 7 of Set 14 | ust-maya
# Processing Record 8 of Set 14 | gamba
# Processing Record 9 of Set 14 | arlit
# Processing Record 10 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 11 of Set 14 | sinnamary
# Processing Record 12 of Set 14 | ossora
# Processing Record 13 of Set 14 | raahe
# Processing Record 14 of Set 14 | turukhansk
# Processing Record 15 of Set 14 | iwaki
# Processing Record 16 of Set 14 | amga
# Processing Record 17 of Set 14 | sens
# Processing Record 18 of Set 14 | ituiutaba
# Processing Record 19 of Set 14 | mogadishu
# Processing Record 20 of Set 14 | puerto escondido
# Processing Record 21 of Set 14 | kemang
# Processing Record 22 of Set 14 | qaqortoq
# Processing Record 23 of Set 14 | gat
# Processing Record 24 of Set 14 | boffa
# Processing Record 25 of Set 14 | vysokogornyy
# Processing Record 26 of Set 14 | cairns
# Processing Record 27 of Set 14 | pila
# Processing Record 28 of Set 14 | trincomalee
# Processing Record 29 of Set 14 | gombong
# Processing Record 30 of Set 14 | goure
# Processing Record 31 of Set 14 | madison
# Processing Record 32 of Set 14 | sergeyevka
# Processing Record 33 of Set 14 | iskateley
# Processing Record 34 of Set 14 | trabzon
# Processing Record 35 of Set 14 | quebrada bonita adentro
# Processing Record 36 of Set 14 | dakar
# Processing Record 37 of Set 14 | dien bien
# City not found. Skipping...
# Processing Record 38 of Set 14 | santiago del estero
# Processing Record 39 of Set 14 | lorengau
# Processing Record 40 of Set 14 | esperance
# Processing Record 41 of Set 14 | maragogi
# Processing Record 42 of Set 14 | mul
# Processing Record 43 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 14 | listvyanka
# Processing Record 45 of Set 14 | pecos
# Processing Record 46 of Set 14 | ustye
# Processing Record 47 of Set 14 | higuey
# City not found. Skipping...
# Processing Record 48 of Set 14 | sidi bu zayd
# City not found. Skipping...
# Processing Record 49 of Set 14 | teknaf
# Processing Record 50 of Set 14 | almargem do bispo
# Processing Record 1 of Set 15 | manaure
# Processing Record 2 of Set 15 | portland
# Processing Record 3 of Set 15 | sikonge
# Processing Record 4 of Set 15 | zagare
# Processing Record 5 of Set 15 | torremolinos
# Processing Record 6 of Set 15 | scarborough
# Processing Record 7 of Set 15 | andenes
# Processing Record 8 of Set 15 | sofiysk
# City not found. Skipping...
# Processing Record 9 of Set 15 | deputatskiy
# Processing Record 10 of Set 15 | middle island
# Processing Record 11 of Set 15 | clarence town
# Processing Record 12 of Set 15 | diamantino
# Processing Record 13 of Set 15 | denpasar
# Processing Record 14 of Set 15 | nisia floresta
# Processing Record 15 of Set 15 | atar
# Processing Record 16 of Set 15 | vilhena
# Processing Record 17 of Set 15 | nevel
# Processing Record 18 of Set 15 | desaguadero
# Processing Record 19 of Set 15 | broken hill
# Processing Record 20 of Set 15 | palimbang
# Processing Record 21 of Set 15 | walvis bay
# Processing Record 22 of Set 15 | mujiayingzi
# Processing Record 23 of Set 15 | guia lopes da laguna
# Processing Record 24 of Set 15 | kytlym
# City not found. Skipping...
# Processing Record 25 of Set 15 | krasnyy chikoy
# Processing Record 26 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 27 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 28 of Set 15 | gorontalo
# Processing Record 29 of Set 15 | kupang
# Processing Record 30 of Set 15 | beloha
# Processing Record 31 of Set 15 | roald
# Processing Record 32 of Set 15 | san cristobal
# Processing Record 33 of Set 15 | gweta
# Processing Record 34 of Set 15 | kangalassy
# Processing Record 35 of Set 15 | shimanovsk
# Processing Record 36 of Set 15 | iberia
# Processing Record 37 of Set 15 | jawhar
# Processing Record 38 of Set 15 | terrace bay
# Processing Record 39 of Set 15 | mananjary
# Processing Record 40 of Set 15 | jiangyou
# Processing Record 41 of Set 15 | majene
# Processing Record 42 of Set 15 | eyl
# Processing Record 43 of Set 15 | bay roberts
# Processing Record 44 of Set 15 | tocopilla
# Processing Record 45 of Set 15 | pasni
# Processing Record 46 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 47 of Set 15 | urulga
# City not found. Skipping...
# Processing Record 48 of Set 15 | meadow lake
# Processing Record 49 of Set 15 | orapa
# Processing Record 50 of Set 15 | bonthe
# Processing Record 1 of Set 16 | cimitarra
# Processing Record 2 of Set 16 | axim
# Processing Record 3 of Set 16 | kant
# Processing Record 4 of Set 16 | mina
# Processing Record 5 of Set 16 | kiama
# Processing Record 6 of Set 16 | orlovskiy
# Processing Record 7 of Set 16 | hualmay
# Processing Record 8 of Set 16 | taburi
# City not found. Skipping...
# Processing Record 9 of Set 16 | gillette
# Processing Record 10 of Set 16 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 16 | malya
# Processing Record 12 of Set 16 | ayacucho
# Processing Record 13 of Set 16 | morondava
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 691

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Vaini -21.2000 -175.2000     78.96        83          75
# 1  Port Lincoln -34.7333  135.8667     61.41        65         100
# 2         Kenai  60.5544 -151.2583     47.14        93         100
# 3      Suoyarvi  62.0833   32.3500     39.11        92          58
# 4      Canutama  -6.5339  -64.3831     80.46        69          96
# 5  Kruisfontein -34.0033   24.7314     59.88        85           0
# 6         Tabuk  17.4189  121.4443     71.94        92          45
# 7    Nikolskoye  59.7035   30.7861     46.29        94         100
# 8       Rikitea -23.1203 -134.9692     74.44        65          14
# 9       Qaanaaq  77.4840  -69.3632      9.45        72          19
#
#    Wind Speed Country Current Description
# 0        8.05      TO       broken clouds
# 1       10.38      AU     overcast clouds
# 2        4.61      US          light rain
# 3        3.69      RU       broken clouds
# 4        4.41      BR     overcast clouds
# 5        9.06      ZA           clear sky
# 6        2.17      PH    scattered clouds
# 7        4.92      RU     overcast clouds
# 8        2.30      PF          few clouds
# 9        7.54      GL          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Vaini      TO -21.2000 -175.2000     78.96        83          75
# 1  Port Lincoln      AU -34.7333  135.8667     61.41        65         100
# 2         Kenai      US  60.5544 -151.2583     47.14        93         100
# 3      Suoyarvi      RU  62.0833   32.3500     39.11        92          58
# 4      Canutama      BR  -6.5339  -64.3831     80.46        69          96
# 5  Kruisfontein      ZA -34.0033   24.7314     59.88        85           0
# 6         Tabuk      PH  17.4189  121.4443     71.94        92          45
# 7    Nikolskoye      RU  59.7035   30.7861     46.29        94         100
# 8       Rikitea      PF -23.1203 -134.9692     74.44        65          14
# 9       Qaanaaq      GL  77.4840  -69.3632      9.45        72          19
#
#    Wind Speed Current Description
# 0        8.05       broken clouds
# 1       10.38     overcast clouds
# 2        4.61          light rain
# 3        3.69       broken clouds
# 4        4.41     overcast clouds
# 5        9.06           clear sky
# 6        2.17    scattered clouds
# 7        4.92     overcast clouds
# 8        2.30          few clouds
# 9        7.54          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
